# %% [markdown]
# ## Emotion Detection
# # Importing Libraries

# %%
import matplotlib.pyplot as plt
from glob import glob           #to create a listto store all elements present in a directory
import cv2
import random
import os
# %matplotlib inline
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense,Input,Dropout,Flatten,Conv2D
from tensorflow.keras.layers import BatchNormalization,Activation,MaxPooling2D
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG,Image
import tensorflow as tf
print("Tensorflow version",tf.__version__)
# Out:
# Tensorflow version 2.15.0

# %% [markdown]
# **Exploring the Dataset**

# %%
images=glob("train/**/**")
for i in range(9):
    image=random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %%
img_size=48
batch_size=64
datagen_train=ImageDataGenerator()
train_generator=datagen_train.flow_from_directory("train/",
                                                 target_size=(img_size,img_size),
                                                  color_mode="grayscale",
                                                  batch_size=batch_size,
                                                  class_mode="categorical",
                                                  shuffle=True
                                                 )

datagen_validation=ImageDataGenerator()
validation_generator=datagen_train.flow_from_directory("test/",
                                                 target_size=(img_size,img_size),
                                                  color_mode="grayscale",
                                                  batch_size=batch_size,
                                                  class_mode="categorical",
                                                  shuffle=True
                                                 )
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# **Defining Model**

# %%
def Convolution(input_tensor,filters,kernel_size):
    x=Conv2D(filters=filters,kernel_size=kernel_size,padding="same")(input_tensor)
    x=BatchNormalization()(x)
    x=Activation('relu')(x)
    x=MaxPooling2D(pool_size=(2,2))(x)
    x=Dropout(0.25)(x)
    return x

# %%
def Dense_f(input_tensor,nodes):
    x=Dense(nodes)(input_tensor)
    x=BatchNormalization()(x)
    x=Activation("relu")(x)
    x=Dropout(0.25)(x)
    return x

# %%
def model_fer(Input_shape):
    inputs=Input(Input_shape)
    conv_1=Convolution(inputs,32,(3,3))
    conv_2=Convolution(inputs,64,(3,3))
    conv_3=Convolution(inputs,128,(3,3))
    
    flatten=Flatten()(conv_3)
    dense_1=Dense_f(flatten,256)
    
    output=Dense(7,activation="softmax")(dense_1)
    model=Model(inputs=[inputs],outputs=[output])
    
    model.compile(loss=['categorical_crossentropy'],optimizer='adam',metrics=['accuracy'])
    
    return model

# %%
model=model_fer((48,48,1))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\asus\anaconda3\envs\emotion_detection_course\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\asus\anaconda3\envs\emotion_detection_course\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\asus\anaconda3\envs\emotion_detection_course\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Bat  (None, 48, 48, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18879239 (72.02 MB)
# Trainable params: 18878471 (72.02 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %% [markdown]
# **Initializing the Model**

# %%
epochs=15
steps_per_epoch=train_generator.n//train_generator.batch_size
validation_steps=validation_generator.n//validation_generator.batch_size

checkpoint=ModelCheckpoint("model_weights.h5",monitor="val_accuracy",save_weights_only=True,mode="max",verbose=1)
callbacks=[checkpoint]

# %% [markdown]
# **Training the Model**

# %%
history=model.fit(
    x=train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=callbacks)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From C:\Users\asus\anaconda3\envs\emotion_detection_course\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\asus\anaconda3\envs\emotion_detection_course\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 448/448 [==============================] - ETA: 0s - loss: 1.6481 - accuracy: 0.3754
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 468s 1s/step - loss: 1.6481 - accuracy: 0.3754 - val_loss: 1.5205 - val_accuracy: 0.4170
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3521 - accuracy: 0.4853
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 344s 767ms/step - loss: 1.3521 - accuracy: 0.4853 - val_loss: 1.6873 - val_accuracy: 0.3260
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1848 - accuracy: 0.5563
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 434s 968ms/step - loss: 1.1848 - accuracy: 0.5563 - val_loss: 1.5423 - val_accuracy: 0.3841
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0569 - accuracy: 0.6127
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 346s 773ms/step - loss: 1.0569 - accuracy: 0.6127 - val_loss: 1.5416 - val_accuracy: 0.4231
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9268 - accuracy: 0.6621
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 20278s 45s/step - loss: 0.9268 - accuracy: 0.6621 - val_loss: 1.6732 - val_accuracy: 0.4032
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8075 - accuracy: 0.7084
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 418s 932ms/step - loss: 0.8075 - accuracy: 0.7084 - val_loss: 1.6978 - val_accuracy: 0.4106
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.7551
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 353s 789ms/step - loss: 0.6924 - accuracy: 0.7551 - val_loss: 1.6727 - val_accuracy: 0.4541
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5938 - accuracy: 0.7937
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 355s 791ms/step - loss: 0.5938 - accuracy: 0.7937 - val_loss: 1.5471 - val_accuracy: 0.4770
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5013 - accuracy: 0.8258
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 342s 763ms/step - loss: 0.5013 - accuracy: 0.8258 - val_loss: 1.8039 - val_accuracy: 0.4523
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4411 - accuracy: 0.8495
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 605s 1s/step - loss: 0.4411 - accuracy: 0.8495 - val_loss: 1.7380 - val_accuracy: 0.4743
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3869 - accuracy: 0.8682
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 348s 777ms/step - loss: 0.3869 - accuracy: 0.8682 - val_loss: 1.9493 - val_accuracy: 0.4442
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3364 - accuracy: 0.8881
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 337s 751ms/step - loss: 0.3364 - accuracy: 0.8881 - val_loss: 2.0004 - val_accuracy: 0.4393
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2981 - accuracy: 0.9013
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 337s 752ms/step - loss: 0.2981 - accuracy: 0.9013 - val_loss: 1.9363 - val_accuracy: 0.4999
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2768 - accuracy: 0.9110
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 343s 765ms/step - loss: 0.2768 - accuracy: 0.9110 - val_loss: 1.9204 - val_accuracy: 0.4877
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2440 - accuracy: 0.9175
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 346s 771ms/step - loss: 0.2440 - accuracy: 0.9175 - val_loss: 1.9925 - val_accuracy: 0.4898

# %% [markdown]
# **Model Evaluation**

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 16s 135ms/step - loss: 1.9924 - accuracy: 0.4898
# [1.9924023151397705, 0.48983004689216614]

# %% [markdown]
# **Plotting Loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Model loss")
plt.legend(["Train","validation"],loc="upper left")
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **plot accuracy**

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Model Accuracy")
plt.legend(["Train","validation"],loc="upper left")
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **Saving Model**

# %%
model_json=model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
